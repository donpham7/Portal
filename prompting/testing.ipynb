# %%
# %pip install google-genai PyMuPDF
# Out:
# ...
#      ---------------------------------------- 0.0/41.6 kB ? eta -:--:--
#      ---------------------------------------  41.0/41.6 kB 1.9 MB/s eta 0:00:01
#      -------------------------------------- 41.6/41.6 kB 978.9 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/68.0 kB ? eta -:--:--
#      ---------------------------------------- 68.0/68.0 kB 1.9 MB/s eta 0:00:00
# ...
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# ...
#    ---------------------------------------- 0.0/226.8 kB ? eta -:--:--
#    ---------------------------------------  225.3/226.8 kB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 226.8/226.8 kB 3.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/18.7 MB ? eta -:--:--
#    - -------------------------------------- 0.7/18.7 MB 23.1 MB/s eta 0:00:01
#    ---- ----------------------------------- 2.3/18.7 MB 29.1 MB/s eta 0:00:01
# ...

# %%
from google import genai
import fitz

# %%
def extract_text_from_pdf(pdf_path):
    doc = fitz.open(pdf_path)
    text = ""
    for page in doc:
        text += page.get_text()
    doc.close()
    return text

# %%
pdf_text = extract_text_from_pdf("UMNwriteup.pdf")

# %%
client = genai.Client(api_key="AIzaSyDAtOO9m0zixcFdtnAk6ZAJ1pP-Dz91J2A")

response = client.models.generate_content(
    model="gemini-2.5-flash", contents=f"""This is a health document. You are creating tasks for a patient to do by scanning the health document. This should be specific actions for the patient, quantitative when possible. Do not summarize any patient specific data. The tasks should be actions that the user needs to do; Do not include tasks that medical professionals have performed on the user, these should only be future tasks that the user will need to complete themselves. Each task needs to be checked off, so keep this in mind for wording. Format the tasks by numbering each one with a short but descriptive header, and including the specific actions and purpose of the task below that. Keep in mind low literacy level, but not at the cost of incorrect medical vocab (to prevent miscommunication). Create 3-20 tasks, depending on what makes sense. Each separate medication and or PT exercise, etc is a separate task. This is a health document. You are creating tasks for a patient to do by scanning the health document. This should be specific actions for the patient, quantitative when possible. Do not summarize any patient specific data. The tasks should be actions that the user needs to do; Do not include tasks that medical professionals have performed on the user, these should only be future tasks that the user will need to complete themselves. Each task needs to be checked off, so keep this in mind for wording. Format the tasks by numbering each one with a short but descriptive header, and including the specific actions and purpose of the task below that. The headers should ve quantified if applicable (e.g. take 2 mg Aspirin twice daily). Keep in mind low literacy level, but not at the cost of incorrect medical vocab (to prevent miscommunication). Create 3-20 tasks, depending on what makes sense. Each separate medication and or PT exercise, etc is a separate task. Put this into json format. Use the header of each task as the key, and then any extra details as the value. json format:\n\n{pdf_text}"""
)
print(response.text)
# Out:
# ```json
# {
#   "Take Prescribed Aspirin": "Take the aspirin medicine exactly as your doctor tells you. This will help decrease the risk of a heart attack.",
#   "Take Prescribed Nitrates for Pain": "Take the nitrate medicine exactly as your doctor tells you, especially if you have chest pain. This will help with your chest pain and to lower your blood pressure.",
#   "Start an Exercise Program": "After you are discharged from the hospital and your doctor approves, begin a regular exercise routine. This will help improve your heart health and manage your weight.",
#   "Begin a Weight Loss Program": "After you are discharged from the hospital and your doctor approves, start a plan to help you lose weight. This will improve your overall health and reduce strain on your heart.",
#   "Follow a Low-Fat Diet": "After you are discharged from the hospital, choose foods that are low in fat. This will help manage your cholesterol and improve your heart health.",
# ...
