# %%
# %pip install google-genai PyMuPDF
# Out:
# ...
#   Using cached google_genai-1.25.0-py3-none-any.whl.metadata (41 kB)
# ...
#   Using cached pymupdf-1.26.3-cp39-abi3-win_amd64.whl.metadata (3.4 kB)
# ...
#   Using cached anyio-4.9.0-py3-none-any.whl.metadata (4.7 kB)
# ...
#   Using cached google_auth-2.40.3-py2.py3-none-any.whl.metadata (6.2 kB)
# ...
#   Using cached tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# ...
#   Using cached websockets-15.0.1-cp313-cp313-win_amd64.whl.metadata (7.0 kB)
# ...
#   Using cached rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# ...
# Using cached google_genai-1.25.0-py3-none-any.whl (226 kB)
# Using cached anyio-4.9.0-py3-none-any.whl (100 kB)
# Using cached google_auth-2.40.3-py2.py3-none-any.whl (216 kB)
# ...
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 10.9 MB/s eta 0:00:00
# Using cached rsa-4.9.1-py3-none-any.whl (34 kB)
# Using cached tenacity-8.5.0-py3-none-any.whl (28 kB)
# Using cached websockets-15.0.1-cp313-cp313-win_amd64.whl (176 kB)
# ...

# %%
from google import genai
import fitz
import json

# %%
def extract_text_from_pdf(pdf_path):
    doc = fitz.open(pdf_path)
    text = ""
    for page in doc:
        text += page.get_text()
    doc.close()
    return text

# %%
pdf_text = extract_text_from_pdf("UMNwriteup.pdf")

# %%
client = genai.Client(api_key="AIzaSyDAtOO9m0zixcFdtnAk6ZAJ1pP-Dz91J2A")

response = client.models.generate_content(
    model="gemini-2.5-flash", contents=f"Summarize this document:\n\n{pdf_text}"
)
print(response.text)
# Out:
# This document is a medical history and physical examination report for Pamela Rogers, a 56-year-old female who presented to the Emergency Department with a week-long history of worsening chest pain.
#
# The patient describes the chest pain as dull and aching, originating in the left para-sternal area and radiating to her neck, accompanied by shortness of breath. Initially triggered by exertion (gardening), the pain episodes have increased in frequency and duration, culminating in an episode that awakened her from sleep, prompting her visit.
#
# Her past medical history includes hypertension (diagnosed 3 years prior but medication discontinued) and a total abdominal hysterectomy/bilateral oophorectomy. She has a significant family history of premature coronary artery disease (father died at 54 of a heart attack).
#
# ...

# %%
resp = """
```json
[
  {
    "filename": "Sample Written History and Physical Examination",
    "key_details": {
      "para-sternal area": "The region next to the breastbone.",
      "palpitations": "A feeling of a rapid, strong, or irregular heartbeat.",
      "exertional dyspnea": "Shortness of breath that happens when you are doing physical activity.",
      "orthopnea": "Shortness of breath that happens when you lie flat.",
      "paroxysmal nocturnal dyspnea": "Sudden attacks of severe shortness of breath that wake you up at night.",
      "GERD sx": "Symptoms of acid reflux disease, where stomach acid flows back into the food pipe.",
      "palpable pain": "Pain that can be felt by touching the affected area.",
      "claudication": "Pain in the leg caused by too little blood flow, usually during exercise.",
      "HTN": "High blood pressure.",
      "TAH with BSO": "A surgery where the uterus, fallopian tubes, and ovaries were removed.",
      "hormone replacement therapy": "Medication used to replace hormones that the body no longer makes.",
      "premature CAD": "Heart disease caused by narrowed arteries that develops earlier than expected.",
      "Bunionectomy": "Surgery to remove a bunion, a bony bump at the base of the big toe.",
      "peptic ulcer disease": "Sores that develop on the lining of the stomach, lower esophagus, or small intestine.",
      "cimetidine": "A medication used to reduce stomach acid.",
      "rash and hives": "Red, itchy bumps or patches on the skin, often an allergic reaction.",
      "OTC ibuprofen (Advil)": "Over-the-counter pain reliever like Advil.",
      "hypertension": "High blood pressure.",
      "dysphagia": "Difficulty swallowing.",
      "epigastric pain": "Pain in the upper middle part of the belly, just below the breastbone.",
      "dysuria": "Pain or discomfort when urinating.",
      "nocturia": "Waking up at night to urinate.",
      "polyuria": "Urinating more often than normal or passing a large amount of urine.",
      "hematuria": "Blood in the urine.",
      "arthralgias": "Joint pain.",
      "numbness": "Loss of feeling in a part of the body.",
      "incoordination": "Difficulty with smooth, controlled movements.",
      "alert, oriented and cooperative": "Aware of surroundings, knowing who and where they are, and able to follow instructions.",
      "sclera and conjunctiva": "The white part of the eye and the clear membrane covering it.",
      "Fundoscopic examination": "An exam where a doctor looks at the back of your eye.",
      "hemorrhage": "Bleeding.",
      "Tympanic membranes": "Eardrums.",
      "external auditory canals": "Ear canals.",
      "Nasal mucosa": "The lining inside the nose.",
      "Oral pharynx": "The part of the throat behind the mouth.",
      "erythema": "Redness, often of the skin or mucous membranes.",
      "exudate": "Fluid that leaks out of blood vessels into nearby tissues.",
      "adenopathy": "Swollen or enlarged lymph nodes.",
      "cervical or supraclavicular areas": "Areas in the neck or above the collarbone where lymph nodes are located.",
      "Trachea": "Windpipe.",
      "thyroid gland": "A gland in the neck that makes hormones.",
      "Carotid artery upstroke": "The feeling of the pulse in the neck arteries.",
      "bruits": "Unusual sounds heard over an artery, often due to turbulent blood flow.",
      "Jugular venous pressure": "A measurement of the pressure in the large veins in the neck, which can indicate heart function.",
      "Lungs are clear to auscultation and percussion": "The lungs sound normal when listened to with a stethoscope and tapped.",
      "crackles heard in the lung bases bilaterally": "Crackling sounds in both lower parts of the lungs, often due to fluid in the lungs.",
      "PMI is in the 5th inter-costal space at the mid clavicular line": "The strongest heartbeat is felt in the fifth space between the ribs, under the middle of the collarbone.",
      "grade 2/6 systolic decrescendo murmur": "A soft heart murmur heard when the heart contracts, which gets quieter as it continues.",
      "second right inter-costal space": "The second space between the ribs on the right side of the chest.",
      "Third heart sound": "An extra heart sound that can indicate a problem with heart function.",
      "fourth heart sound or rub": "Additional unusual heart sounds.",
      "Cystic changes are noted in the breasts bilaterally": "Non-cancerous fluid-filled sacs found in both breasts.",
      "distention": "Swelling or bloating.",
      "bowel sounds": "Sounds made by the intestines as they move food.",
      "paraumbilical area": "The area around the belly button.",
      "splenomegaly": "Enlarged spleen.",
      "liver span": "The measured size of the liver.",
      "cyanosis": "Bluish discoloration of the skin due to lack of oxygen.",
      "clubbing": "Enlargement of the fingertips and toes, often with downward-curving nails, due to chronic low oxygen.",
      "edema": "Swelling caused by excess fluid in body tissues.",
      "Peripheral pulses": "Pulses felt in the arms and legs.",
      "femoral, popliteal, anterior tibial, dorsalis pedis, brachial, and radial areas": "Locations in the legs and arms where pulses can be felt.",
      "Nodes": "Lymph nodes, which are small glands that filter harmful substances.",
      "inguinal areas": "The groin areas.",
      "rectal sphincter tone": "The tightness of the muscle that controls bowel movements.",
      "guaiac negative": "A test result indicating no blood was found in the stool.",
      "external genitalia": "The outer sex organs.",
      "vagina and cervix": "Parts of the female reproductive system.",
      "speculum examination": "An exam using a tool to view the vagina and cervix.",
      "Bimanual examination": "An exam where the doctor uses both hands to feel the internal organs.",
      "uterus, ovaries": "Parts of the female reproductive system.",
      "Cranial nerves II-XII": "Nerves that originate from the brain and control various functions like vision, smell, and muscle movement.",
      "Motor and sensory examination": "Tests to check muscle strength, movement, and how well you feel touch or pain.",
      "Gait and cerebellar function": "Tests to check how you walk and the part of your brain that controls balance and coordination.",
      "Reflexes": "Automatic responses of the body.",
      "Dyspnea": "Shortness of breath.",
      "Early surgical menopause": "Menopause that occurs because the ovaries were removed by surgery.",
      "Recent onset HTN": "High blood pressure that has started recently.",
      "Systolic ejection murmur": "A heart murmur heard when the heart contracts and blood is pushed out.",
      "OTC non-steroidal analgesic use": "Taking over-the-counter pain relievers that are not steroids.",
      "angina pectoris": "Chest pain or discomfort caused by reduced blood flow to the heart.",
      "ischemic cardiac origin": "Coming from the heart due to lack of blood flow.",
      "coronary artery disease": "A condition where the heart's blood vessels are narrowed or blocked.",
      "unstable angina": "A severe type of chest pain that can happen at rest and signals a heart attack may be coming.",
      "Gastro-esophageal reflux disease (GERD)": "A condition where stomach acid frequently flows back into the food pipe, causing heartburn.",
      "recumbency": "Lying down.",
      "pulmonary component": "Involvement of the lungs.",
      "pulmonary infection": "An infection in the lungs.",
      "ischemic heart disease": "Heart problems caused by narrowed heart arteries, leading to a lack of blood flow.",
      "left ventricular dysfunction": "When the main pumping chamber of the heart (left ventricle) is not working as well as it should.",
      "congestive heart failure": "A condition where the heart cannot pump enough blood to meet the body's needs.",
      "myocardial ischemia": "Reduced blood flow to the heart muscle.",
      "secondary cause of hypertension": "High blood pressure caused by another medical condition.",
      "ASCVD of the renal artery": "Hardening of the arteries that supply blood to the kidneys.",
      "renovascular hypertension": "High blood pressure caused by narrowed kidney arteries.",
      "hypertensive retinopathy": "Damage to the blood vessels in the back of the eye due to high blood pressure.",
      "left ventricular hypertrophy": "Thickening of the muscle wall of the heart's main pumping chamber.",
      "valvular heart disease": "A condition affecting the heart valves.",
      "aortic stenosis": "A condition where the main valve leading out of the heart (aortic valve) is narrowed.",
      "aortic valvular murmur": "A specific sound heard from the aortic heart valve.",
      "carotid upstroke": "The feel of the pulse in the neck arteries.",
      "NSAID use": "Taking non-steroidal anti-inflammatory drugs, a type of pain reliever.",
      "Fibrocystic breast disease": "A common, non-cancerous condition where breasts feel lumpy or rope-like.",
      "impending myocardial infarction": "A serious heart attack that is about to happen.",
      "platelet inhibitors": "Medications that prevent blood clots by stopping platelets from sticking together.",
      "aspirin": "A common medication used to thin the blood and relieve pain.",
      "nitrates": "Medications used to widen blood vessels and improve blood flow to the heart, often for chest pain.",
      "occlusion": "A blockage in a blood vessel.",
      "analgesic": "A medication used to relieve pain.",
      "morphine": "A strong pain-relieving medication.",
      "HMG Co-reductases": "A class of medications used to lower cholesterol, also known as statins.",
      "cardiac catheterization": "A procedure where a thin tube is guided through a blood vessel to the heart to diagnose or treat heart conditions.",
      "non-invasive tests": "Medical tests that do not involve breaking the skin or entering the body.",
      "diuretics": "Medications that help the body get rid of excess salt and water, often called water pills.",
      "volume overload": "Too much fluid in the body.",
      "ventriculogram": "A special X-ray test of the heart's pumping chambers.",
      "wall motion abnormalities": "Problems with how the heart muscle moves and pumps blood.",
      "BUN/Creatinine": "Blood tests that check kidney function.",
      "electrolytes": "Blood tests that measure important salts and minerals in the body.",
      "baseline EKG": "An initial heart tracing (electrocardiogram) that records the electrical activity of the heart."
    },
    "personal_takeaways": "Based on the medical document, Pamela Rogers, a 56-year-old female, is experiencing chest pain consistent with angina pectoris, potentially unstable angina, which means there's a serious risk of a heart attack. This is due to underlying coronary artery disease, for which she has risk factors like high blood pressure, early surgical menopause, and a family history of heart disease. Her shortness of breath, along with specific heart and lung findings, suggests her heart's main pumping chamber may not be working well, possibly leading to congestive heart failure. Doctors are also investigating if her recent high blood pressure is caused by a problem with the blood vessels to her kidneys, and a heart murmur suggests a possible narrowing of her main heart valve. She also has a history of stomach ulcers, experiences upper belly pain, and has common non-cancerous breast changes and back pain. She has a penicillin allergy. The plan includes medication to prevent heart attacks and manage symptoms, lifestyle changes, and further tests to get a clearer picture of her heart condition and overall health."
  },
  {
    "1. Monitor Your Chest Pain": "Pay close attention to any changes or increase in your chest pain. This helps us know if your heart condition is getting worse or if you might be having a heart attack.",
    "2. Take Your Aspirin Daily": "Take the prescribed aspirin every day. This medicine helps prevent blood clots and reduces your risk of a heart attack.",
    "3. Use Nitrates for Chest Pain (As Directed)": "If you feel chest pain, take the prescribed nitrate medication as directed. This medicine helps widen your blood vessels, easing chest pain and lowering your blood pressure.",
    "4. Take Diuretics for Shortness of Breath (As Prescribed)": "Take the prescribed diuretic medication every day. This medicine helps your body get rid of extra water, which can reduce your shortness of breath and help lower your blood pressure.",
    "5. Follow a Low-Fat Diet": "Choose foods that are low in fat. This diet helps manage your cholesterol and supports heart health.",
    "6. Start an Exercise Program": "Begin a regular exercise routine that is appropriate for you. Talk to your doctor about what type and how much exercise is safe. Exercise helps improve your heart health and manage your weight.",
    "7. Participate in a Weight Loss Program": "Work towards losing weight through healthy eating and exercise. Losing weight helps reduce strain on your heart and improves overall health.",
    "8. Take Cholesterol-Lowering Medication (If Prescribed)": "If your doctor prescribes it, take your cholesterol-lowering medication (like statins) as directed. This medicine helps lower high cholesterol levels, which is good for your heart.",
    "9. Schedule Your Heart Procedure (Cardiac Catheterization)": "Contact the hospital or clinic to schedule your cardiac catheterization. This important procedure helps doctors get a detailed look at your heart and blood vessels.",
    "10. Attend Lab Work Appointments": "Go to all scheduled blood tests, including checks for your kidney function (BUN/Creatinine) and body salts (electrolytes). These tests help your doctor monitor your health and how your medications are working.",
    "11. Get a Baseline EKG": "Attend your appointment for a baseline EKG, which is a heart tracing. This test records your heart's electrical activity and helps your doctor understand its current function."
  }
]
```
"""

# %%
result = json.loads(resp[8:-4])
print(result)
# Out:
# [{'filename': 'Sample Written History and Physical Examination', 'key_details': {'para-sternal area': 'The region next to the breastbone.', 'palpitations': 'A feeling of a rapid, strong, or irregular heartbeat.', 'exertional dyspnea': 'Shortness of breath that happens when you are doing physical activity.', 'orthopnea': 'Shortness of breath that happens when you lie flat.', 'paroxysmal nocturnal dyspnea': 'Sudden attacks of severe shortness of breath that wake you up at night.', 'GERD sx': 'Symptoms of acid reflux disease, where stomach acid flows back into the food pipe.', 'palpable pain': 'Pain that can be felt by touching the affected area.', 'claudication': 'Pain in the leg caused by too little blood flow, usually during exercise.', 'HTN': 'High blood pressure.', 'TAH with BSO': 'A surgery where the uterus, fallopian tubes, and ovaries were removed.', 'hormone replacement therapy': 'Medication used to replace hormones that the body no longer makes.', 'premature CAD': 'Heart disea
# ...

# %%
def parse_pdf_contents(file_path):
    """
    Taking pdf and storing in a json: all words, per page a dictionary of text and coordinates

    Args:
        filename (string): Filename of pdf.

    Returns:
        JSON: content of pdf and coordinates for each word.
    """


    try:
        doc = fitz.open(file_path)
        result = {}
        all_words = []

        for page_num in range(len(doc)):
            page = doc[page_num]
            words = page.get_text("words")

            word_data = []
            for w in words:
                x0, y0, x1, y1, text, *_ = w
                word_data.append({
                    "text": text,
                    "bbox": [x0, y0, x1, y1]
                })
                all_words.append(text)


            result[f"page_{page_num + 1}"] = word_data
        
        result["all_words"] = all_words
        return result


    except FileNotFoundError:
        return jsonify({"error": f"{file_path} not found"}), 404

# %%
parsed_pdf_contents = parse_pdf_contents("C:\\Users\\brock\\Git\\Portal\\data\\uploads\\UMNwriteup.pdf")
word_coordinates_dict = {}
for key_detail in result[0]["key_details"].keys():
    print(key_detail)
    first_bbox = None
    last_bbox = None
    list_key_detail = key_detail.split(' ')
    for page_key in parsed_pdf_contents.keys():
        if page_key[0:5] != "page_":
            break
        for doc_idx in range(len(parsed_pdf_contents[page_key])):
            if parsed_pdf_contents[page_key][doc_idx]["text"] == list_key_detail[0]:
                if first_bbox == None:
                    first_bbox = parsed_pdf_contents[page_key][doc_idx]["bbox"]
                match = True
                for key_word_idx in range(len(list_key_detail)):
                    
                    if parsed_pdf_contents[page_key][doc_idx + key_word_idx]["text"] != list_key_detail[key_word_idx]:
                        first_bbox = None
                        match = False
                        break
                if (match == True):
                    last_bbox = parsed_pdf_contents[page_key][doc_idx + key_word_idx]["bbox"]
        word_coordinates_dict[key_detail] = [first_bbox, last_bbox]
# Out:
# para-sternal area
# palpitations
# exertional dyspnea
# orthopnea
# paroxysmal nocturnal dyspnea
# GERD sx
# palpable pain
# claudication
# HTN
# TAH with BSO
# hormone replacement therapy
# premature CAD
# Bunionectomy
# peptic ulcer disease
# cimetidine
# rash and hives
# OTC ibuprofen (Advil)
# hypertension
# dysphagia
# epigastric pain
# dysuria
# nocturia
# polyuria
# hematuria
# arthralgias
# numbness
# incoordination
# alert, oriented and cooperative
# sclera and conjunctiva
# Fundoscopic examination
# hemorrhage
# Tympanic membranes
# external auditory canals
# Nasal mucosa
# Oral pharynx
# erythema
# exudate
# adenopathy
# cervical or supraclavicular areas
# Trachea
# thyroid gland
# Carotid artery upstroke
# bruits
# Jugular venous pressure
# Lungs are clear to auscultation and percussion
# crackles heard in the lung bases bilaterally
# PMI is in the 5th inter-costal space at the mid clavicular line
# grade 2/6 systolic decrescendo murmur
# second right inter-costal space
# ...

# %%
print(word_coordinates_dict)
# Out:
# {'para-sternal area': [[122.05772399902344, 299.8950500488281, 170.080810546875, 309.93902587890625], [172.58909606933594, 299.8950500488281, 190.63409423828125, 309.93902587890625]], 'palpitations': [None, None], 'exertional dyspnea': [None, None], 'orthopnea': [None, None], 'paroxysmal nocturnal dyspnea': [None, None], 'GERD sx': [None, None], 'palpable pain': [None, None], 'claudication': [None, None], 'HTN': [[35.999664306640625, 568.935791015625, 54.56576919555664, 578.9797973632812], [145.55162048339844, 434.4155578613281, 164.11952209472656, 444.45953369140625]], 'TAH with BSO': [[35.999664306640625, 610.3357543945312, 54.07976531982422, 620.3797607421875], [74.93547821044922, 610.3357543945312, 93.9236831665039, 620.3797607421875]], 'hormone replacement therapy': [None, None], 'premature CAD': [None, None], 'Bunionectomy': [[90.00209045410156, 703.45458984375, 147.05130004882812, 713.4985961914062], [90.00209045410156, 703.45458984375, 147.05130004882812, 713.4985961914062]],
# ...
