# %%
# %pip install google-genai PyMuPDF
# Out:
# ...
#      ---------------------------------------- 0.0/41.6 kB ? eta -:--:--
#      ---------------------------------------  41.0/41.6 kB ? eta -:--:--
#      ---------------------------------------- 41.6/41.6 kB 1.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/68.0 kB ? eta -:--:--
#      ---------------------------------------- 68.0/68.0 kB 1.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/226.8 kB ? eta -:--:--
#    ---------------------------------------- 226.8/226.8 kB 4.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/100.9 kB ? eta -:--:--
#    ---------------------------------------- 100.9/100.9 kB 2.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/216.1 kB ? eta -:--:--
#    --------------------------------------- 216.1/216.1 kB 12.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/73.5 kB ? eta -:--:--
# ...

# %%
from google import genai
import fitz

# %%
def extract_text_from_pdf(pdf_path):
    doc = fitz.open(pdf_path)
    text = ""
    for page in doc:
        text += page.get_text()
    doc.close()
    return text

# %%
pdf_text = extract_text_from_pdf("UMNwriteup.pdf")

# %%
client = genai.Client(api_key="AIzaSyDAtOO9m0zixcFdtnAk6ZAJ1pP-Dz91J2A")

response = client.models.generate_content(
    model="gemini-2.5-flash", contents=f"""You are medical report summarizer, provide what a 
    doctor would want to explain to a patient who doesn't understand difficult healthcare 
    terminology. Selected words and phrases should be specific to healthcare and involve complex 
    terminology without including simple words. This list should include EVERY word that could be 
    possibly confusing for a patient to read. Absolutely DO NOT include elementary words about history, 
    symptoms, characterization, or patient identification. Include every disease name, condition symptom, 
    or anatomical location. Absolutely DO NOT include source information. Absolutely DO NOT provide details 
    on hospital locations or terms. Avoid choosing phrases over direct words when possible. DO NO incliude
      the words admissmion, history, or chief complaint. Response must be in a JSON format. Key is quotes 
      or a word directly from the document. Value is your summarization:\n\n{pdf_text}"""
)
print(response.text)
# Out:
# ```json
# {
#   "para-sternal area": "the part of the chest next to the breastbone.",
#   "radiated": "spread from one area to another.",
#   "Dyspnea": "difficulty breathing.",
#   "nausea": "feeling sick to your stomach.",
#   "vomiting": "throwing up.",
#   "dizziness": "feeling lightheaded or unsteady.",
#   "palpitations": "feeling like your heart is beating too fast, too hard, or skipping a beat.",
#   "exertional dyspnea": "shortness of breath that happens when you do physical activity.",
#   "orthopnea": "shortness of breath that occurs when lying flat.",
#   "paroxysmal nocturnal dyspnea": "sudden shortness of breath that wakes you up at night.",
#   "GERD": "a condition where stomach acid flows back into the tube connecting your mouth to your stomach, causing heartburn.",
#   "palpable pain": "pain that can be felt by touch.",
#   "claudication": "pain, cramping, or tiredness in the legs that happens with activity and goes away with rest, often due to poor blood flow.",
# ...

# %%
client = genai.Client(api_key="AIzaSyDAtOO9m0zixcFdtnAk6ZAJ1pP-Dz91J2A")

response = client.models.generate_content(
    model="gemini-2.5-flash", contents=f"""If this patient had diabetes, please list out the key takeaways 
    and important information that might complicate their pre existing diabetes condition. Please include concerns with 
    treatment options, symptoms, and diagnosis considerations. Response must be 
    in a JSON format. Keys are phrases or words from the text. Value is your summarization of why these are concerns based on the patient info:\n\n{pdf_text}"""
)
print(response.text)
# Out:
# ```json
# {
#   "Chest pains": "If the patient had diabetes, the chest pain could represent 'silent ischemia' due to autonomic neuropathy, where nerve damage blunts typical pain perception. This can lead to delayed diagnosis of serious cardiac events like unstable angina or myocardial infarction, as symptoms might be atypical (e.g., dyspnea, fatigue, or arm/jaw discomfort without significant chest pain).",
#   "History of HTN": "Diabetes significantly exacerbates hypertension and accelerates the development and progression of cardiovascular and renal complications. The combination increases the risk of diabetic nephropathy and more severe renovascular hypertension, making blood pressure management more challenging and critical. Intensive blood pressure control is paramount in diabetic patients.",
# ...
